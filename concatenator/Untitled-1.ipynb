# %%
import pandas as pd
from pathlib import Path

# %%
df_201306 = pd.read_csv(Path("../2013-citibike-tripdata/201306-citibike-tripdata.csv"))
df_201307 = pd.read_csv(Path("../2013-citibike-tripdata/201307-citibike-tripdata.csv"))
df_201308 = pd.read_csv(Path("../2013-citibike-tripdata/201308-citibike-tripdata.csv"))
df_201309 = pd.read_csv(Path("../2013-citibike-tripdata/201309-citibike-tripdata.csv"))
df_201310 = pd.read_csv(Path("../2013-citibike-tripdata/201310-citibike-tripdata.csv"))
df_201311 = pd.read_csv(Path("../2013-citibike-tripdata/201311-citibike-tripdata.csv"))
df_201312 = pd.read_csv(Path("../2013-citibike-tripdata/201312-citibike-tripdata.csv"))

df_201306.head()

#Go up a level ..2013-citibike-tripdata
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           695  2013-06-01 00:00:01  2013-06-01 00:11:36               444
# 1           693  2013-06-01 00:00:08  2013-06-01 00:11:41               444
# 2          2059  2013-06-01 00:00:44  2013-06-01 00:35:03               406
# 3           123  2013-06-01 00:01:04  2013-06-01 00:03:07               475
# 4          1521  2013-06-01 00:01:22  2013-06-01 00:26:43              2008
#
#        start station name  start station latitude  start station longitude  \
# 0      Broadway & W 24 St               40.742354               -73.989151
# 1      Broadway & W 24 St               40.742354               -73.989151
# 2  Hicks St & Montague St               40.695128               -73.995951
# 3     E 15 St & Irving Pl               40.735243               -73.987586
# 4   Little West St & 1 Pl               40.705693               -74.016777
#
# ...

# %%
new_pf = pd.concat([df_201306, df_201307, df_201308, df_201309, df_201310, df_201311, df_201312], axis=0)
new_pf.tail()
# Out:
#         tripduration            starttime             stoptime  \
# 443961          1014  2013-12-31 23:55:56  2014-01-01 00:12:50
# 443962           682  2013-12-31 23:57:04  2014-01-01 00:08:26
# 443963          1520  2013-12-31 23:57:44  2014-01-01 00:23:04
# 443964          1166  2013-12-31 23:58:14  2014-01-01 00:17:40
# 443965           677  2013-12-31 23:58:16  2014-01-01 00:09:33
#
#         start station id                 start station name  \
# 443961               350              Clinton St & Grand St
# 443962               538                    W 49 St & 5 Ave
# 443963               281  Grand Army Plaza & Central Park S
# 443964               492                    W 33 St & 7 Ave
# 443965               463                    9 Ave & W 16 St
#
#         start station latitude  start station longitude  end station id  \
# 443961               40.715595               -73.987030           532.0
# 443962               40.757952               -73.977876          2006.0
# ...

# %%
new_pf.to_csv("2013_bike_data.csv")
